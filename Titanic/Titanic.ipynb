# %% [markdown]
# ### Uploading data files from Git

# %% [markdown]
# ## Adding files and folders to ignore files

# %%
from google.colab import userdata
from google.colab import drive
drive.mount('/content/drive')
# !git config --global user.name "Ho139523"
# !git config --global user.email "answereeee4@gmail.com"
token=userdata.get('token')
username='Ho139523'
repo='Machine_Learning'
proj_folder='Titanic'

# !mkdir Titanic
# %cd Titanic
# !mkdir Data
# %cd ../
# !git init
# !git remote add origin https://github.com/{username}/{repo}
# !git config core.sparsecheckout true
# !git sparse-checkout set {proj_folder}
# !git pull origin HEAD:main
# !cp /content/drive/MyDrive/Data/Titanic/test.csv /content/{proj_folder}/Data
# !cp /content/drive/MyDrive/Data/Titanic/train.csv /content/{proj_folder}/Data
# Out:
# Mounted at /content/drive
# /content/Titanic
# /content
# hint: Using 'master' as the name for the initial branch. This default branch name
# hint: is subject to change. To configure the initial branch name to use in all
# hint: of your new repositories, which will suppress this warning, call:
# hint:
# hint: 	git config --global init.defaultBranch <name>
# hint:
# hint: Names commonly chosen instead of 'master' are 'main', 'trunk' and
# hint: 'development'. The just-created branch can be renamed via this command:
# hint:
# hint: 	git branch -m <name>
# Initialized empty Git repository in /content/.git/
# remote: Enumerating objects: 173, done.
# remote: Counting objects: 100% (173/173), done.
# remote: Compressing objects: 100% (127/127), done.
# remote: Total 173 (delta 37), reused 99 (delta 15), pack-reused 0
# Receiving objects: 100% (173/173), 8.54 MiB | 17.08 MiB/s, done.
# Resolving deltas: 100% (37/37), done.
# From https://github.com/Ho139523/Machine_Learning
# ...

# %%
# !cd /content/
# !touch .gitignore
# !echo "sample_data/" >> .gitignore
# !echo ".config/" >> .gitignore
# !echo ".git/" >> .gitignore

# %% [markdown]
# <h1 style="color: #F0F8FF">Importing basic prerequisite packages</h1>
#
# <img src="https://user-images.githubusercontent.com/1217238/65354639-dd928f80-dba4-11e9-833b-bc3e8c6a737d.png" style="height: 100px">
# <img SRC="https://seeklogo.com/images/P/pandas-logo-56829C6445-seeklogo.com.png" style="height: 200px;display: block; margin: 0 auto;">
# <img src="https://user-images.githubusercontent.com/315810/92255284-156f1180-eea0-11ea-9d2d-be8262670e8c.png" style="height: 200px">

# %%
import numpy as np
import pandas as pd
import seaborn as sb

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/0/05/Scikit_learn_logo_small.svg/1280px-Scikit_learn_logo_small.svg.png" style="height: 100px">

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error, r2_score

# %%
train=pd.read_csv('/content/Titanic/Data/train.csv')
train=train.dropna()
features=['Sex','Age','Fare','Pclass']
Y=train['Survived']
X=train[features]
X=pd.get_dummies(X)
train
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-7ca7d0b751be> in <cell line: 1>()
# ----> 1 train=pd.read_csv('/content/Titanic/Data/train.csv')
#       2 train=train.dropna()
#       3 features=['Sex','Age','Fare','Pclass']
#       4 Y=train['Survived']
#       5 X=train[features]
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
# ...

# %%
X_train, X_test, Y_train, Y_test=train_test_split(X,Y, test_size=0.15, random_state=0)
Y_train

# %%
X_train

# %%
Y_test=Y_test.reset_index(drop=True)

# %%
sk_Model=RandomForestClassifier(n_estimators=100, max_depth=5, random_state=1)

# %%
sk_Model.fit(X,Y)

# %%
Y_pred=sk_Model.predict(X_test)

# %%
Comparision=pd.DataFrame(Y_pred, columns=['Survived_Predicted'])

# %%
Comparision['Survived_trained']=Y_test

# %%
Comparision

# %%
print(f"Mean squared error is: {mean_squared_error(Y_test, Y_pred)}")
print(f"Root mean squared error is: {np.sqrt(mean_squared_error(Y_test, Y_pred))}")
print(f"R squared error is: {r2_score(Y_test, Y_pred)}")
print(f"Mean absolute error is: {mean_absolute_error(Y_test, Y_pred)}")
print(f"Mean absolute percentage error is: {mean_absolute_percentage_error(Y_test, Y_pred)*100}")
